# %%
from utils_3d import *
from data_loading import *
import os
import sdf_helper as sh


# if __name__ == "__main__":
#     file_path = os.path.join(
#         '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024ab+2/10kev25磁场',
#         # '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024a/10kev无磁场',
#         'density0018.sdf'
#     )

#     output_dir = './output'
#     os.makedirs(output_dir, exist_ok=True)

#     # x_ranges = [(16.5, 17.2), (17.2, 17.9), (17.9, 18.7), (18.7, 19.5),(19.5,20.4),(20.4,21.2),(21.2,22),(22,22.8)]
#     x_ranges = [ (18, 19),(19, 19.7), (19.7, 20.4), (20.4, 21.2),(21.2,22),(22,22.7),(22.7,23.5)] #
#     csv_path = os.path.join(output_dir, '密度25磁场平滑17-results.csv')

#     # 写入表头（若文件不存在）
#     if not os.path.exists(csv_path):
#         with open(csv_path, 'w', newline='') as f:
#             csv.writer(f).writerow(['x_min', 'x_max', '1e_width(um)', 'z_left(um)', 'z_right(um)', 'total_density'])

#     # 分析每个区域
#     for x_min, x_max in x_ranges:
#         result = analyze_region(file_path, (x_min, x_max), save=False, output_dir=output_dir, save_csv=True, csv_path=csv_path)
#         if result:
#             print(f"x ∈ ({x_min}, {x_max}) → width = {result['1e_width']:.2f} μm, total = {result['total_density']:.2e}")

# %%
file_path = os.path.join(
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024ab+2/10kev25磁场',
    # '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024a/10kev无磁场',
    'density0018.sdf'
)

x,y,z = load_xyz_grid(file_path)
ne = load_ne_data(file_path,species='Electron')
ek = load_ek_data(file_path,species='Electron')

# # 有磁场
# a1 = ek_mean_variance(ek, x, y, z,[(18,19)], [-1.88,1.616984985], [-1.88,1.616984985])
# a2 = ek_mean_variance(ek, x, y, z,[(19,19.7)], [-1.112,0.701045045], [-1.112,0.701045045])
# a3 = ek_mean_variance(ek, x, y, z,[(19.7,20.4)], [-0.968,0.886142142], [-0.968,0.886142142])
# a4 = ek_mean_variance(ek, x, y, z,[(21.2,22)], [-1.448,1.898546547], [-1.448,1.898546547])
# a5 = ek_mean_variance(ek, x, y, z,[(22,22.7)], [-1.624,1.754418418], [-1.624,1.754418418])
# a6 = ek_mean_variance(ek, x, y, z,[(22.7,23.5)], [-1.064,1.299259259], [-1.064,1.299259259])

# # 有磁场
# a11 = ek_mean_variance(ek*ne, x, y, z,[(18,19)], [-1.88,1.616984985], [-1.88,1.616984985])
# a21 = ek_mean_variance(ek*ne, x, y, z,[(19,19.7)], [-1.112,0.701045045], [-1.112,0.701045045])
# a31 = ek_mean_variance(ek*ne, x, y, z,[(19.7,20.4)], [-0.968,0.886142142], [-0.968,0.886142142])
# a41 = ek_mean_variance(ek*ne, x, y, z,[(21.2,22)], [-1.448,1.898546547], [-1.448,1.898546547])
# a51 = ek_mean_variance(ek*ne, x, y, z,[(22,22.7)], [-1.624,1.754418418], [-1.624,1.754418418])
# a61 = ek_mean_variance(ek*ne, x, y, z,[(22.7,23.5)], [-1.064,1.299259259], [-1.064,1.299259259])
# Out:
# Reading file /media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024ab+2/10kev25磁场/density0018.sdf
# t() = time
# x(1501, 1001, 1001) = grid
# y(1501, 1001, 1001) = grid
# z(1501, 1001, 1001) = grid
# xc(1500, 1000, 1000) = grid_mid
# yc(1500, 1000, 1000) = grid_mid
# zc(1500, 1000, 1000) = grid_mid

# %%
data = sh.getdata(file_path)
sh.list_variables(data)
# Out:
# Absorption_Fraction_of_Laser_Energy_Absorbed____ <class 'sdf.BlockConstant'> [1]
# Absorption_Total_Laser_Energy_Injected__J_ <class 'sdf.BlockConstant'> [1]
# CPUs_Current_rank <class 'sdf.BlockPlainVariable'> [0, 0, 0]
# CPUs_Original_rank <class 'sdf.BlockPlainVariable'> [ 3,  1, 50]
# Derived_Average_Particle_Energy_Electron <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Derived_Average_Particle_Energy_Ion_H <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Derived_Average_Particle_Energy_Photon <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Derived_Number_Density_Electron <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Derived_Number_Density_Ion_H <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Derived_Number_Density_Photon <class 'sdf.BlockPlainVariable'> [1500, 1000, 1000]
# Grid_CPUs_Original_rank <class 'sdf.BlockPlainMesh'> [ 4,  2, 51]
# Grid_CPUs_Original_rank_mid <class 'sdf.BlockPlainMesh'> [ 3,  1, 50]
# ...

# %%
# 无磁场
file_path = os.path.join(
    # '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024ab+2/10kev25磁场',
    '/media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024a/10kev无磁场',
    'density0018.sdf'
)

ne1,ek1,x1,y1,z1 = load_density_data(file_path)

# 有磁场
b1 = ek_mean_variance(ek1, x1, y1, z1,[(16.5,17.2)], [-1.0800000000000007,1.3606486486486473], [-1.0800000000000007,1.3606486486486473])
b2 = ek_mean_variance(ek1, x1, y1, z1,[(17.2,17.9)], [-0.8080000000000006,0.8141981981981975], [-0.8080000000000006,0.8141981981981975])
b3 = ek_mean_variance(ek1, x1, y1, z1,[(18.7,19.5)], [-0.7600000000000008,0.4157037037037027], [-0.7600000000000008,0.4157037037037027])
b4 = ek_mean_variance(ek1, x1, y1, z1,[(19.5,20.4)], [-1.1120000000000005,1.3421341341341333], [-1.1120000000000005,1.3421341341341333])
b5 = ek_mean_variance(ek1, x1, y1, z1,[(20.4,21.2)], [-1.2720000000000007,0.7899339339339333], [-1.2720000000000007,0.7899339339339333])
b6 = ek_mean_variance(ek1, x1, y1, z1,[(21.2,22)], [-1.7040000000000006,1.0744264264264256], [-1.7040000000000006,1.0744264264264256])

# 有磁场
b11 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(16.5,17.2)], [-1.0800000000000007,1.3606486486486473], [-1.0800000000000007,1.3606486486486473])
b21 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(17.2,17.9)], [-0.8080000000000006,0.8141981981981975], [-0.8080000000000006,0.8141981981981975])
b31 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(18.7,19.5)], [-0.7600000000000008,0.4157037037037027], [-0.7600000000000008,0.4157037037037027])
b41 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(19.5,20.4)], [-1.1120000000000005,1.3421341341341333], [-1.1120000000000005,1.3421341341341333])
b51 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(20.4,21.2)], [-1.2720000000000007,0.7899339339339333], [-1.2720000000000007,0.7899339339339333])
b61 = ek_mean_variance(ek1*ne1, x1, y1, z1,[(21.2,22)], [-1.7040000000000006,1.0744264264264256], [-1.7040000000000006,1.0744264264264256])
# Out:
# Reading file /media/lan/4248e56e-6d9a-4026-afad-e8b1d59ceab0/epoch-set2/epoch3d/ju2024a/10kev无磁场/density0018.sdf
# t() = time
# x(1501, 1001, 1001) = grid
# y(1501, 1001, 1001) = grid
# z(1501, 1001, 1001) = grid
# xc(1500, 1000, 1000) = grid_mid
# yc(1500, 1000, 1000) = grid_mid
# zc(1500, 1000, 1000) = grid_mid
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [16.5, 17.2] μm: 平均能量 = 4.247517e-15 J, 方差 = 1.590907e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [17.2, 17.9] μm: 平均能量 = 7.585099e-15 J, 方差 = 6.924735e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [18.7, 19.5] μm: 平均能量 = 1.801241e-14 J, 方差 = 7.924036e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.5, 20.4] μm: 平均能量 = 1.558500e-14 J, 方差 = 8.681744e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [20.4, 21.2] μm: 平均能量 = 1.639969e-14 J, 方差 = 1.313773e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [21.2, 22.0] μm: 平均能量 = 1.861784e-14 J, 方差 = 1.184016e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [16.5, 17.2] μm: 平均能量 = 1.833967e-15 J, 方差 = 1.092188e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# ...

# %%
# 有磁场
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [18.0, 19.0] μm: 平均能量 = 9.595559e-15 J, 方差 = 2.000844e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.0, 19.7] μm: 平均能量 = 1.706785e-14 J, 方差 = 1.138602e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.7, 20.4] μm: 平均能量 = 1.715653e-14 J, 方差 = 1.037611e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [21.2, 22.0] μm: 平均能量 = 1.247705e-14 J, 方差 = 2.032919e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [22.0, 22.7] μm: 平均能量 = 1.456734e-14 J, 方差 = 1.929397e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [22.7, 23.5] μm: 平均能量 = 1.432440e-14 J, 方差 = 2.024404e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [18.0, 19.0] μm: 平均能量 = 3.639127e-15 J, 方差 = 1.054207e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.0, 19.7] μm: 平均能量 = 6.682825e-15 J, 方差 = 6.318293e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.7, 20.4] μm: 平均能量 = 6.727434e-15 J, 方差 = 6.591984e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [21.2, 22.0] μm: 平均能量 = 5.587935e-15 J, 方差 = 1.518705e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [22.0, 22.7] μm: 平均能量 = 7.765101e-15 J, 方差 = 1.829075e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [22.7, 23.5] μm: 平均能量 = 7.692364e-15 J, 方差 = 1.945880e-27

# 无磁场
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [16.5, 17.2] μm: 平均能量 = 4.247517e-15 J, 方差 = 1.590907e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [17.2, 17.9] μm: 平均能量 = 7.585099e-15 J, 方差 = 6.924735e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [18.7, 19.5] μm: 平均能量 = 1.801241e-14 J, 方差 = 7.924036e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.5, 20.4] μm: 平均能量 = 1.558500e-14 J, 方差 = 8.681744e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [20.4, 21.2] μm: 平均能量 = 1.639969e-14 J, 方差 = 1.313773e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [21.2, 22.0] μm: 平均能量 = 1.861784e-14 J, 方差 = 1.184016e-26
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [16.5, 17.2] μm: 平均能量 = 1.833967e-15 J, 方差 = 1.092188e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [17.2, 17.9] μm: 平均能量 = 3.531564e-15 J, 方差 = 5.367810e-28
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [18.7, 19.5] μm: 平均能量 = 9.266194e-15 J, 方差 = 6.646246e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [19.5, 20.4] μm: 平均能量 = 7.303034e-15 J, 方差 = 6.512842e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [20.4, 21.2] μm: 平均能量 = 6.277753e-15 J, 方差 = 6.946511e-27
# 各个 x 范围内能量方差和平均能量（单位：J）:
# [21.2, 22.0] μm: 平均能量 = 7.900206e-15 J, 方差 = 7.902958e-27
